# %% [markdown]
# ## LOAD LIBRARIES....

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import os
import matplotlib.pyplot as plt
# %matplotlib inline

from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from os import path
from pandas import Series, DataFrame
from sklearn.preprocessing import Imputer
from fancyimpute import KNN

from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import Range1d, LabelSet, Label, ColumnDataSource, NumeralTickFormatter
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="682c82c8-f231-4a84-a393-7b4f2f78ab07">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## TEXT ANALYTICS

# %% [markdown]
# ## Available Functions:
# 1. Word-Count
# 2. Word-Count-Viz

# %%
def wordCount(data):
    cwd=os.getcwd()
    file=open(cwd + '/' + data, 'r')
    
    counter={}
    for word in file.read().split():
        if word not in counter:
            counter[word] = 1
        else:
            counter[word] += 1
    
    counterFrame = Series(counter).to_frame()
    counterFrame.columns = ['Count']
    
    return counterFrame.sort_values('Count', ascending=False)

# %% [markdown]
# # PRE-PROCESSING FUNCTIONS:

# %% [markdown]
# ### Available Functions:
# 1. Missing-Summary
# 2. Drop-Coloumns-Rows
# 3. Impute-Data
# 4. Missing-Summary-Viz

# %%
#FUNCTION: MISSING-SUMMARY
    #Input: any sort of tabular data
    #Returns: a data-frame with total missing & percentage of data missing from each column of input data
    
def missingSummary(data):
    total=data.isnull().sum()
    percent=data.isnull().sum() / data.isnull().count() * 100
    df_missingData = round(pd.concat([total, percent], axis=1, keys=['Total', 'Percent']).sort_values('Percent', 
                                                                                               ascending=False),2)
    df_missingData.index.name = 'Attributes '
    df_missingData.columns.name = 'Missing-Summary'
    
    missingSummary_Viz(df_missingData)
    
    return df_missingData

# %%
#FUNCTION: clean_DropColRows
    #Input: data (tabular), missingData (from missingSummary), percent cutoff for columns to drop (e.g. more than 80% missing = 80% is the cutoff)
        #percent cutoff for rows to drop
    #Returns: missingSummary + cleaned data frame with dropped columns and rows
    
def clean_DropColRows(data, missingData, col_cutoff, row_cutoff):
    cols_to_drop=list(missingData.loc[missingData['Percent'] >= col_cutoff].index)
    rows_to_drop=list(missingData.loc[missingData['Percent'] <= row_cutoff].index)
    
    df_droppedColRows = data.copy()
    df_droppedColRows = df_droppedColRows.drop(cols_to_drop, axis=1)
    df_droppedColRows = df_droppedColRows.dropna(subset=rows_to_drop, how='any')
    
    df_droppedColRows.reindex(np.arange(len(df_droppedColRows)))
    df_droppedColRows.columns.name = 'Attributes'
    
    df_missingData_dropColRows = missingSummary(df_droppedColRows)
    
    return df_droppedColRows, df_missingData_dropColRows

# %%
#FUNCTION: imputedData
    #Input: data (any tabular data) + imputation method 
        #methods (backfill, forward-fill, mean, median, most_frequent, knn)
    #Returns: imputed data frame (imputation using specified method)

def imputeData(data, method):
    if method in ('bfill', 'ffill'):
        df_imputed = data.fillna(method=method, axis=1, inplace=False)
    elif method in ('mean', 'median', 'most_frequent'):
        imp = Imputer(missing_values=np.NaN, strategy=method, axis=0, copy=True)
        df_imputed = imp.fit_transform(data)
        df_imputed = round(DataFrame(df_imputed),0)
    else:
        nn = int(input('How many nearest neighbors? '))
        df_imputed = KNN(k=nn).complete(data)
        df_imputed = round(DataFrame(df_imputed),0)
        
    df_imputed.reindex(np.arange(len(df_imputed)))
    df_imputed.columns = data.columns
    
    df_missingData_imputed = missingSummary(df_imputed)
    
    return df_imputed, df_missingData_imputed

# %%
def missingSummary_Viz(data):
    features = list(reversed(data.index))
    values = (data['Percent'].sort_values(ascending=True)/100)
    source = ColumnDataSource(dict(x=round(values,2), y=features))
    
    p = figure(y_range=features, plot_width=800, plot_height=600)
    p.hbar(y=features, height=0.6, left=0, right=values, color='darkblue')

    labels = LabelSet(x='x', y='y', text='x', level='glyph', x_offset=5, y_offset=-10, source=source, render_mode='canvas')
    p.add_layout(labels)

    #---------------------------------PLOT FORMATTING---------------------------------------#

    #-----OUTLINE-----#
    p.outline_line_width = 8
    p.outline_line_alpha = 0.3
    p.outline_line_color = "navy"

    #-----BACKGROUND-----#
    p.background_fill_color = "beige"
    p.background_fill_alpha = 0.5

    #-----X-AXIS-----#
    p.xaxis.axis_label = "Percent Missing (%)"
    p.xaxis.axis_label_text_font_size = "12pt"
    #p.xaxis.axis_line_width = 2
    #p.xaxis.axis_line_color = "red"

    #-----Y-AXIS-----#
    p.yaxis.axis_label = "Attributes"
    p.yaxis.major_label_orientation = "horizontal"
    p.yaxis.axis_label_text_font_size = "12pt"
    #p.yaxis.axis_line_width = 2
    #p.yaxis.major_label_text_color = "orange"

    #-----TITLE-----#
    p.title.text_font_style = "bold"
    p.title.align = 'center'
    p.title.text = "Missing Data Summary"
    p.title.align = "center"
    p.title.text_font_size = "20px"
    #p.title.text_color = "olive"
    #p.title.text_font = "times"

    #-----TICK-FORMAT-----#
    p.xaxis[0].formatter = NumeralTickFormatter(format="0.0%")

    #-----BOUNDS-----#
    p.xaxis.bounds = (0.0, 100.0)
    p.x_range = Range1d(0, 1)

    #-----BORDERS-----#
    p.min_border_top = 50
    p.min_border_bottom = 50
    
    return show(p)

# %% [markdown]
# ## VALIDATION TESTS...

# %%
sampleData=pd.read_excel('SampleData-2.xls')

# %%
missingDF = missingSummary(sampleData)
missingDF
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e8e47614-31ea-4694-b393-86f124c0aa1b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e8e47614-31ea-4694-b393-86f124c0aa1b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e8e47614-31ea-4694-b393-86f124c0aa1b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e8e47614-31ea-4694-b393-86f124c0aa1b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4aa1c0cc-7dc1-4ebd-ac47-1b52619e1ffb":{"roots":{"references":[{"attributes":{},"id":"9fd3b930-4299-43b6-9726-a65e1ecb7fc5","type":"BasicTicker"},{"attributes":{"level":"glyph","plot":{"id":"4b10417d-3b71-4235-8bd8-ef9647bf9919","subtype":"Figure","type":"Plot"},"source":{"id":"5a693ab3-6c04-4f59-871f-0f9ac613a1cd","type":"ColumnDataSource"},"text":{"field":"x"},"x":{"field":"x"},"x_offset":{"value":5},"y":{"field":"y"},"y_offset":{"value":-10}},"id":"88ed48d0-5d7e-4f81-b5e7-70a5ee26213d","type":"LabelSet"},{"attributes":{"plot":{"id":"4b10417d-3b71-4235-8bd8-ef9647bf9919","subtype":"Figure","type":"Plot"}},"id":"0e27d6fc-aca8-4a6f-b0a8
# Missing-Summary                Total  Percent
# Attributes
# Room service speed              9338    93.38
# Quality of business center      9232    92.32
# Timeliness of airport shuttle   9071    90.71
# Overall fitness center          7871    78.71
# Accuracy of bill                4808    48.08
# Bar ambiance                    4684    46.84
# Breakfast quality               4357    43.57
# Internet quality                3744    37.44
# Ease of making reservation      3744    37.44
# Cleanliness of bathroom          592     5.92
# Quietness of room                 96     0.96
# Attitude of hotel staff           74     0.74
# Cleanliness of room               73     0.73
# Overall Experience                 0     0.00

# %%
droppedDf, missing_droppedDf = clean_DropColRows(sampleData, missingDF, 80, 5)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2a4e0bd0-a591-4446-8a83-be639103665c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("2a4e0bd0-a591-4446-8a83-be639103665c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2a4e0bd0-a591-4446-8a83-be639103665c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2a4e0bd0-a591-4446-8a83-be639103665c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e5a8b561-2428-4375-bf8f-f753097d5ca9":{"roots":{"references":[{"attributes":{"overlay":{"id":"2e8b0129-b601-444b-94d4-335373dcc8a5","type":"BoxAnnotation"},"plot":{"id":"e0584d40-c0b8-4f9a-b425-5e5a206bf5d4","subtype":"Figure","type":"Plot"}},"id":"9786728a-4a18-4d3e-b616-6e4862ea03df","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"f3256c36-984f-471e-a1ab-f3f36c64e0d8","type":"Range1d"},{"attributes":{"plot":{"id":"e0584d40-c0b8-4f9a-b425-5e5a206bf5d4","subtype":"Figure","type":"Plot"}},"id":"3452688c-4941-4c46-9295-8d04e800e2c8","type":"SaveTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value":0.6},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"y":{"field":"y"}},"id":"2769d342-338d-43bc-9ec3-14542bfd4b60","type":"HBar"},{"attributes":{},"id":"3b639390-607f-44a5-90cc-c8ae76c1258c","type":"CategoricalTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1f14bc76-dc6b-4476-9a58-1537a35d263d","type":"PanTool"},{"id":"fdfe10aa-0da4-4ae3-a3fc-44a21206c77c","type":"WheelZoomTool"},{"id":"9786728a-4a18-4d3e-b616-6e4862ea03df","type":"BoxZoomTool"},{"id":"3452688c-4941-4c46-9295-8d04e800e2c8","type":"SaveTool"},{"id":"d88f3c7d-e98c-490e-aea6-743771cf5b0f","type":"ResetTool"},{"id":"b5098795-77a5-4083-b900-7a640a1ed9b0","type":"HelpTool"}]},"id":"7a2decfc-dab3-473e-b062-bab614d88670","type":"Toolbar"},{"attributes":{"axis_label":"Percent Missing (%)","axis_label_text_font_size":{"value":"12pt"},"bounds":[0.0,100.0],"formatter":{"id":"137f64c0-657a-45c6-91c7-a99d6675743f","type":"NumeralTickFormatter"},"plot":{"id":"e0584d40-c0b8-4f9a-b425-5e5a206bf5d4","subtype":"Figure","type":"Plot"},"ticker":{"id":"453dcc6c-5239-4fb8-9204-93a7d0e62f4b","type":"BasicTicker"}},"id":"63c12b6b-62c9-45b3-bba9-eec7b3d14b57","type":"LinearAxis"},{"attributes":{"plot":{"id":"e0584d40-c0b8-4f9a-b425-5e5a206bf5d4","subtype":"Figure","type":"Plot"}},"id":"fdfe10aa-0da4-4ae3-a3fc-44a21206c77c","type":"WheelZoomTool"},{"attributes":{},"id":"453dcc6c-5239-4fb8-9204-93a7d0e62f4b","type":"BasicTicker"},{"attributes":{"level":"glyph","plot":{"id":"e0584d40-c0b8-4f9a-b425-5e5a206bf5d4","subtype":"Figure","type":"Plot"},"source":{"id":"ae07d383-94cf-4688-a587-3967c6ef2ea9","type":"ColumnDataSource"},"text":{"field":"x"},"x":{"field":"x"},"x_offset":{"value":5},"y":{"field":"y"},"y_offset":{"value":-10}},"id":"499b1907-55d4-4082-858a-5cd4e9f74dfd","type":"LabelSet"},{"attributes":{"callback":null,"column_names":["right","y"],"data":{"right":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAADW52or9petP2AHzhlR2tc/JLn8h/Tb1z8DK4cW2c7bP32utmJ/2d0/wRcmUwWj3j9N845TdCTpPw==","dtype":"float64","shape":[11]},"y":["Quietness of room","Cleanliness of room","Attitude of hotel staff","Overall Experience","Cleanliness of bathroom","Internet quality","Ease of making reservation","Breakfast quality","Bar ambiance","Accuracy of bill","Overall fitness center"]}},"id":"6e6e4ec5-8f04-4b59-83d5-277fd3a31ce9","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"e0584d40-c0b8-4f9a-b425-5e5a206bf5d4","subtype":"Figure","type":"Plot"},"ticker":{"id":"453dcc6c-5239-4fb8-9204-93a7d0e62f4b","type":"BasicTicker"}},"id":"830ad974-a683-40eb-b5f1-fea1cf226146","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAC4HoXrUbiuP65H4XoUrtc/rkfhehSu1z+F61G4HoXbPxSuR+F6FN4/uB6F61G43j9I4XoUrkfpPw==","dtype":"float64","shape":[11]},"y":["Quietness of room","Cleanliness of room","Attitude of hotel staff","Overall Experience","Cleanliness of bathroom","Internet quality","Ease of making reservation","Breakfast quality","Bar ambiance","Accuracy of bill","Overall fitness center"]}},"id":"ae07d383-94cf-4688-a587-3967c6ef2ea9","type":"ColumnDataSource"},{"attributes":{"axis_label":"Attributes","axis_label_text_font_size":{"value":"12pt"} ...

# %%
missing_droppedDf
# Out:
# Missing-Summary             Total  Percent
# Attributes
# Overall fitness center       7692    78.57
# Accuracy of bill             4686    47.87
# Bar ambiance                 4566    46.64
# Breakfast quality            4254    43.45
# Ease of making reservation   3650    37.28
# Internet quality             3649    37.27
# Cleanliness of bathroom       566     5.78
# Overall Experience              0     0.00
# Attitude of hotel staff         0     0.00
# Cleanliness of room             0     0.00
# Quietness of room               0     0.00

# %%
imputeDf, missing_ImputedDf = imputeData(sampleData, 'knn')
# Out:
# How many nearest neighbors? 3
# Imputing row 1/10000 with 4 missing, elapsed time: 32.912
# Imputing row 101/10000 with 8 missing, elapsed time: 33.006
# Imputing row 201/10000 with 4 missing, elapsed time: 33.075
# Imputing row 301/10000 with 7 missing, elapsed time: 33.169
# Imputing row 401/10000 with 4 missing, elapsed time: 33.274
# Imputing row 501/10000 with 6 missing, elapsed time: 33.342
# Imputing row 601/10000 with 4 missing, elapsed time: 33.428
# Imputing row 701/10000 with 6 missing, elapsed time: 33.521
# Imputing row 801/10000 with 4 missing, elapsed time: 33.605
# Imputing row 901/10000 with 6 missing, elapsed time: 33.689
# Imputing row 1001/10000 with 8 missing, elapsed time: 33.767
# Imputing row 5901/10000 with 3 missing, elapsed time: 38.060
# Imputing row 6001/10000 with 3 missing, elapsed time: 38.140
# Imputing row 6101/10000 with 9 missing, elapsed time: 38.233
# Imputing row 6201/10000 with 7 missing, elapsed time: 38.325
# Imputing row 6301/10000 with 7 missing, elapsed time: 38.429
# Imputing row 6401/10000 with 6 missing, elapsed time: 38.537
# Imputing row 6501/10000 with 6 missing, elapsed time: 38.627
# Imputing row 6601/10000 with 10 missing, elapsed time: 38.717
# Imputing row 6701/10000 with 6 missing, elapsed time: 38.818
# Imputing row 6801/10000 with 6 missing, elapsed time: 38.908
# Imputing row 6901/10000 with 6 missing, elapsed time: 38.997
# Imputing row 7001/10000 with 5 missing, elapsed time: 39.085
# Imputing row 7101/10000 with 5 missing, elapsed time: 39.162
# Imputing row 7201/10000 with 6 missing, elapsed time: 39.246
# Imputing row 7301/10000 with 3 missing, elapsed time: 39.341
# Imputing row 7401/10000 with 3 missing, elapsed time: 39.436
# Imputing row 7501/10000 with 6 missing, elapsed time: 39.524
# Imputing row 7601/10000 with 4 missing, elapsed time: 39.613
# Imputing row 7701/10000 with 6 missing, elapsed time: 39.694
# Imputing row 7801/10000 with 6 missing, elapsed time: 39.785
# Imputing row 7901/10000 with 6 missing, elapsed time: 39.876
# Imputing row 8001/10000 with 5 missing, elapsed time: 39.964
# Imputing row 8101/10000 with 6 missing, elapsed time: 40.087
# Imputing row 8201/10000 with 5 missing, elapsed time: 40.197
# Imputing row 8301/10000 with 9 missing, elapsed time: 40.312
# Imputing row 8401/10000 with 5 missing, elapsed time: 40.406
# Imputing row 8501/10000 with 2 missing, elapsed time: 40.505
# Imputing row 8601/10000 with 4 missing, elapsed time: 40.645
# Imputing row 8701/10000 with 10 missing, elapsed time: 40.761
# Imputing row 8801/10000 with 7 missing, elapsed time: 40.866
# Imputing row 8901/10000 with 5 missing, elapsed time: 40.964
# Imputing row 9001/10000 with 4 missing, elapsed time: 41.058
# Imputing row 9101/10000 with 5 missing, elapsed time: 41.172
# Imputing row 9201/10000 with 6 missing, elapsed time: 41.278
# Imputing row 9301/10000 with 7 missing, elapsed time: 41.362
# Imputing row 9401/10000 with 5 missing, elapsed time: 41.451
# Imputing row 9501/10000 with 6 missing, elapsed time: 41.534
# Imputing row 9601/10000 with 10 missing, elapsed time: 41.619
# Imputing row 9701/10000 with 3 missing, elapsed time: 41.713
# Imputing row 9801/10000 with 8 missing, elapsed time: 41.804
# Imputing row 9901/10000 with 6 missing, elapsed time: 41.918
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a7c1b7e4-aec3-4a57-9520-f9e5a6497598"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a7c1b7e4-aec3-4a57-9520-f9e5a6497598");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a7c1b7e4-aec3-4a57-9520-f9e5a6497598");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a7c1b7e4-aec3-4a57-9520-f9e5a6497598' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f9f5fc4e-cba1-435c-920f-505448ab7fb1":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"b24d0245-cd43-47fc-980c-cd722296fc3c","subtype":"Figure","type":"Plot"},"ticker":{"id":"1f6151f4-96b5-48f8-95c8-557357831fad","type":"CategoricalTicker"}},"id":"94d86ba3-4443-47da-9a5c-67ac5a53275c","type":"Grid"},{"attributes":{},"id":"1f6151f4-96b5-48f8-95c8-557357831fad","type":"CategoricalTicker"},{"attributes":{"plot":{"id":"b24d0245-cd43-47fc-980c-cd722296fc3c","subtype":"Figure","type":"Plot"}},"id":"0dda2c3d-727b-481b-8cd0-3bf9ae6274d4","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value":0.6},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"y":{"field":"y"}},"id":"51a88a20-a161-4b7f-97aa-df34ff09ddc1","type":"HBar"},{"attributes":{"background_fill_alpha":{"value":0.5},"background_fill_color":{"value":"beige"},"below":[{"id":"51487275-49c3-4b84-b9e1-b463a22451a5","type":"LinearAxis"}],"left":[{"id":"81b2b6ed-512f-4678-ab74-49627cbec7c7","type":"CategoricalAxis"}],"min_border_bottom":50,"min_border_top":50,"outline_line_alpha":{"value":0.3},"outline_line_color":{"value":"navy"},"outline_line_width":{"value":8},"plot_width":800,"renderers":[{"id":"51487275-49c3-4b84-b9e1-b463a22451a5","type":"LinearAxis"},{"id":"57fd5f49-3fd8-4304-a731-5f630545689c","type":"Grid"},{"id":"81b2b6ed-512f-4678-ab74-49627cbec7c7","type":"CategoricalAxis"},{"id":"94d86ba3-4443-47da-9a5c-67ac5a53275c","type":"Grid"},{"id":"ffef4e15-fb77-4cc0-8006-3b9a63884be4","type":"BoxAnnotation"},{"id":"eb478068-9fe6-4870-baae-ea67dac924ea","type":"GlyphRenderer"},{"id":"ef2031b3-994c-41f4-b68d-2a57c4496935","type":"LabelSet"}],"title":{"id":"56295885-de4f-49ac-9fd6-9e788340556b","type":"Title"},"tool_events":{"id":"85e98019-99bc-46d8-b8f8-1b2fe28731e4","type":"ToolEvents"},"toolbar":{"id":"34496d9b-30e3-403d-a840-b10294f3adcb","type":"Toolbar"},"x_range":{"id":"1ea82c44-edce-43e7-9846-c1e0fc8c6476","type":"Range1d"},"y_range":{"id":"baa0135c-8765-45a8-a2e8-090574288046","type":"FactorRange"}},"id":"b24d0245-cd43-47fc-980c-cd722296fc3c","subtype":"Figure","type":"Plot"},{"attributes":{"axis_label":"Percent Missing (%)","axis_label_text_font_size":{"value":"12pt"},"bounds":[0.0,100.0],"formatter":{"id":"a35cb328-a6a7-43e1-84ac-f86de8d42c43","type":"NumeralTickFormatter"},"plot":{"id":"b24d0245-cd43-47fc-980c-cd722296fc3c","subtype":"Figure","type":"Plot"},"ticker":{"id":"9b0d20a5-f9a8-4344-ad33-1933a5e9a935","type":"BasicTicker"}},"id":"51487275-49c3-4b84-b9e1-b463a22451a5","type":"LinearAxis"},{"attributes":{"plot":{"id":"b24d0245-cd43-47fc-980c-cd722296fc3c","subtype":"Figure","type":"Plot"}},"id":"21e84e51-5084-40dd-ab0c-ad07011db06e","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"ffef4e15-fb77-4cc0-8006-3b9a63884be4","type":"BoxAnnotation"},"plot":{"id":"b24d0245-cd43-47fc-980c-cd722296fc3c","subtype":"Figure","type":"Plot"}},"id":"5f5a27af-19e3-4d32-b22b-daca01afc731","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["right","y"],"data":{"right":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA==","dtype":"float64","shape":[14]},"y":["Room service speed","Overall fitness center","Timeliness of airport shuttle","Quality of business center","Accuracy of bill","Bar ambiance","Cleanliness of bathroom","Breakfast quality","Quietness of room","Cleanliness of room","Attitude of hotel staff","Ease of making reservation","Internet quality","Overall Experience"]}},"id":"39b9e1ff-a931-4b36-99df-fd7e0a89efd3","type":"ColumnDataSource"},{"attributes":{"align":"center","plot":null,"text":"Missing Data Summary","text_font_size":{"value":"20px"}},"id":"56295885-de4f-49ac-9fd6-9e788340556b","type":"Title"},{"attributes":{"plot":{"id":"b24d0245-cd43-47fc-980c-cd722296fc3c","subtype":"Figure","type":"Pl ...

# %%
imputeDf, missing_ImputedDf = imputeData(sampleData, 'mean')
imputeDf.head()
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="437814c0-bbc2-4503-bc0e-571c96bd749e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("437814c0-bbc2-4503-bc0e-571c96bd749e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("437814c0-bbc2-4503-bc0e-571c96bd749e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '437814c0-bbc2-4503-bc0e-571c96bd749e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5faab617-08d4-43c0-a9e3-7bded0ca6189":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"ea99e4ae-b6f7-49f6-89e0-6446d06c2119","subtype":"Figure","type":"Plot"},"ticker":{"id":"7a580c77-7ba8-490f-a861-e1f82f4f8dbc","type":"CategoricalTicker"}},"id":"a83e6795-2c4c-492f-b3cd-954c062efbbb","type":"Grid"},{"attributes":{"plot":{"id":"ea99e4ae-b6f7-49f6-89e0-6446d06c2119","subtype":"Figure","type":"Plot"}},"id":"308d2e76-fc70-4add-be7d-1c30bbdf2cea","type":"ResetTool"},{"attributes":{"data_source":{"id":"cee3c109-2416-47a6-85f5-3b4b6bd0a403","type":"ColumnDataSource"},"glyph":{"id":"22f87cab-30cf-41f3-a1f8-3262689dde73","type":"HBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e275b2fa-83ff-4f24-8e95-ffdbac911a38","type":"HBar"},"selection_glyph":null},"id":"7f12ca4b-19d3-49db-bff0-668e44ef373b","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA==","dtype":"float64","shape":[14]},"y":["Room service speed","Overall fitness center","Timeliness of airport shuttle","Quality of business center","Accuracy of bill","Bar ambiance","Cleanliness of bathroom","Breakfast quality","Quietness of room","Cleanliness of room","Attitude of hotel staff","Ease of making reservation","Internet quality","Overall Experience"]}},"id":"e741c881-5154-400f-997a-3cae38e09f04","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"ea99e4ae-b6f7-49f6-89e0-6446d06c2119","subtype":"Figure","type":"Plot"}},"id":"7bd71179-adb3-472a-b825-76cd756a57a6","type":"SaveTool"},{"attributes":{"plot":{"id":"ea99e4ae-b6f7-49f6-89e0-6446d06c2119","subtype":"Figure","type":"Plot"}},"id":"f73e98f2-881f-4e18-863e-40586cc7d564","type":"PanTool"},{"attributes":{"fill_color":{"value":"darkblue"},"height":{"value":0.6},"line_color":{"value":"darkblue"},"right":{"field":"right"},"y":{"field":"y"}},"id":"22f87cab-30cf-41f3-a1f8-3262689dde73","type":"HBar"},{"attributes":{"plot":{"id":"ea99e4ae-b6f7-49f6-89e0-6446d06c2119","subtype":"Figure","type":"Plot"}},"id":"4b8bc836-67a1-44c6-920b-60c32950069b","type":"HelpTool"},{"attributes":{},"id":"7a580c77-7ba8-490f-a861-e1f82f4f8dbc","type":"CategoricalTicker"},{"attributes":{"align":"center","plot":null,"text":"Missing Data Summary","text_font_size":{"value":"20px"}},"id":"7c8d8dbb-23f6-40aa-92b3-f3a076d3b28c","type":"Title"},{"attributes":{"level":"glyph","plot":{"id":"ea99e4ae-b6f7-49f6-89e0-6446d06c2119","subtype":"Figure","type":"Plot"},"source":{"id":"e741c881-5154-400f-997a-3cae38e09f04","type":"ColumnDataSource"},"text":{"field":"x"},"x":{"field":"x"},"x_offset":{"value":5},"y":{"field":"y"},"y_offset":{"value":-10}},"id":"51eb5e22-e650-4894-aa79-133778ac866f","type":"LabelSet"},{"attributes":{},"id":"b2c8708a-20bd-4f21-83c5-0338cfe6a7f7","type":"BasicTicker"},{"attributes":{"callback":null,"factors":["Room service speed","Overall fitness center","Timeliness of airport shuttle","Quality of business center","Accuracy of bill","Bar ambiance","Cleanliness of bathroom","Breakfast quality","Quietness of room","Cleanliness of room","Attitude of hotel staff","Ease of making reservation","Internet quality","Overall Experience"]},"id":"773daf41-5c37-45cf-8a80-056d3fd4cacb","type":"FactorRange"},{"attributes":{},"id":"741b8867-5935-493c-acc1-bd55c4af11b3","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value":0.6},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"y":{"field":"y"}},"id":"e275b2fa-83ff-4f24-8e95-ffdbac911a38","type":"HBar"},{"attributes":{},"id":"13b160ee-bb18-465e-ba0e-fcf90000e95a","type":"CategoricalTickFormatter"},{"attributes":{"axis_label":"Attributes","axis_label_text_font_size":{"value":"12pt"},"formatter":{"id":"13b160ee-bb18-465e-ba0e-fcf90000e95a","ty ...
#    Overall Experience  Internet quality  Ease of making reservation  \
# 0                 9.0              10.0                         8.0
# 1                10.0              10.0                        10.0
# 2                 8.0               9.0                         9.0
# 3                 8.0               9.0                         9.0
# 4                 5.0               9.0                         9.0
#
#    Attitude of hotel staff  Cleanliness of room  Quietness of room  \
# 0                     10.0                 10.0                9.0
# 1                     10.0                 10.0               10.0
# 2                      9.0                 10.0               10.0
# 3                      8.0                  9.0                9.0
# 4                     10.0                 10.0               10.0
#
#    Breakfast quality  Cleanliness of bathroom  Bar ambiance  Accuracy of bill  \
# 0                8.0                     10.0          10.0              10.0
# 1                8.0                     10.0          10.0              10.0
# 2                8.0                      9.0           8.0               8.0
# 3                8.0                     10.0           3.0               7.0
# 4                8.0                     10.0           8.0               8.0
#
#    Quality of business center  Timeliness of airport shuttle  \
# 0                         8.0                            8.0
# 1                         8.0                            8.0
# 2                         8.0                            8.0
# 3                         8.0                            8.0
# 4                         8.0                            8.0
#
#    Overall fitness center  Room service speed
# 0                    10.0                 9.0
# 1                    10.0                10.0
# 2                     8.0                 9.0
# 3                     8.0                 9.0
# 4                     8.0                 9.0

# %%
missing_ImputedDf
# Out:
# Missing-Summary                Total  Percent
# Attributes
# Overall Experience                 0      0.0
# Internet quality                   0      0.0
# Ease of making reservation         0      0.0
# Attitude of hotel staff            0      0.0
# Cleanliness of room                0      0.0
# Quietness of room                  0      0.0
# Breakfast quality                  0      0.0
# Cleanliness of bathroom            0      0.0
# Bar ambiance                       0      0.0
# Accuracy of bill                   0      0.0
# Quality of business center         0      0.0
# Timeliness of airport shuttle      0      0.0
# Overall fitness center             0      0.0
# Room service speed                 0      0.0
