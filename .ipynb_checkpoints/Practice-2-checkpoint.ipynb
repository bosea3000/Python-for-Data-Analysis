# %% [markdown]
# ## IMPORTS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %matplotlib inline
from pandas import Series, DataFrame
from sklearn.preprocessing import Imputer
from fancyimpute import KNN

# %% [markdown]
# ## WORD COUNT

# %%
def wordCounter(text):
    cwd = os.getcwd()
    file = open(cwd + '/' + text, 'r')
    
    counter = {}
    for word in file.read().split():
        if word not in counter:
            counter[word] = 1
        else:
            counter[word] += 1
            
    wcDf = Series(counter).to_frame()
    wcDf.columns = ['Count']
    
    return wcDf.sort_values('Count', ascending=False)

# %% [markdown]
# ## DATA PRE-PROCESSING (SPLIT, MISSING, CLEAN, IMPUTE, QUICK VIZ)

# %%
def splitTarget(data, target):
    targetDf = data[target]
    featuresDf = data.drop(target, axis=1)
    return targetDf, featuresDf

# %%
def missingSummary(data):
    total = data.isnull().sum()
    percent = data.isnull().sum() / data.isnull().count() * 100
    missingSumDf = round(pd.concat([total, percent], axis=1, keys=['Total', 'Percent']).sort_values('Percent', 
                                                                                              ascending=False),2)
    missingSumDf.index.name = 'Attributes'
    missingSumDf.columns.name = 'Missing Summary'
    
    plt.figure(figsize=(10,10))
    ax = sns.barplot(x="Percent", y=missingSumDf.index, data=missingSumDf)
    plt.title('Missing Data Summary')
    plt.xlabel('Percent Missing (%)')
    plt.ylabel('Attributes')
    plt.show()
    
    return missingSumDf

# %%
def cleanedFrame(rawdata, missinngDf, colCutoff, rowCutoff):
    cols2drop = list(missingDf.loc[missingDf['Percent'] >= colCutoff].index)
    rows2drop = list(missingDf.loc[missingDf['Percent'] <= rowCutoff].index)
    
    cleanedDf = rawdata.copy()
    cleanedDf = cleanedDf.drop(cols2drop, axis=1)
    cleanedDf = cleanedDf.dropna(subset=rows2drop, how='any')
    cleanedDf.reindex(np.arange(len(cleanedDf)))
    
    cleaned_missingDf = missingSummary(cleanedDf)
    
    return cleanedDf, cleaned_missingDf

# %%
def imputedFrame(data, process):
    if process in ('bfill', 'ffill'):
        imputedDf = data.fillna(method=process, axis=1, inplace=False)
    elif process in ('mean', 'median', 'most_frequent'):
        imp = Imputer(missing_values=np.NaN, strategy=process, axis=0, copy=True)
        imputedDf = imp.fit_transform(data)
        imputedDf = round(DataFrame(imputedDf),0)
    else: 
        nearestNeighbors = int(input('How many nearest Neighbors? '))
        imputedDf = KNN(k=nearestNeighbors).complete(data)
        imputedDf = round(DataFrame(imputedDf),0)
        
    imputedDf.reindex(np.arange(len(imputedDf)))
    imputedDf.columns = data.columns
    
    imputed_missingDf = missingSummary(imputedDf)
    
    return imputedDf, imputed_missingDf

# %% [markdown]
# ## QUICK VIZ

# %%
def distribution(data):
    cols = list(data.columns)
    for col in cols:
        sns.distplot(data[col], kde=True, rug=True)
        plt.show()

# %% [markdown]
# ## VALIDATION RUNS

# %%
wordCounter('pg11.txt')
# Out:
#               Count
# the            1664
# and             780
# to              773
# a               662
# of              596
# she             484
# said            416
# in              401
# it              356
# was             329
# you             301
# I               260
# as              246
# that            226
# Alice           221
# with            214
# at              211
# her             203
# had             175
# all             168
# be              154
# on              148
# for             146
# or              137
# very            127
# not             122
# this            122
# 'I              121
# little          117
# they            109
# ...             ...
# done.             1
# done,             1
# donations.        1
# donate.           1
# door:             1
# donate,           1
# donate            1
# don't!'           1
# doing?'           1
# doing!'           1
# dogs?'            1
# door--I           1
# door;             1
# ...

# %%
df = pd.read_excel('SampleData-2.xls')

# %%
missingDf = missingSummary(df)

# %%
missingDf
# Out:
# Missing Summary                Total  Percent
# Attributes
# Room service speed              9338    93.38
# Quality of business center      9232    92.32
# Timeliness of airport shuttle   9071    90.71
# Overall fitness center          7871    78.71
# Accuracy of bill                4808    48.08
# Bar ambiance                    4684    46.84
# Breakfast quality               4357    43.57
# Internet quality                3744    37.44
# Ease of making reservation      3744    37.44
# Cleanliness of bathroom          592     5.92
# Quietness of room                 96     0.96
# Attitude of hotel staff           74     0.74
# Cleanliness of room               73     0.73
# Overall Experience                 0     0.00

# %%
cleanedDf, cleanedMissingDf = cleanedFrame(df, missingDf, 80, 5)

# %%
cleanedMissingDf
# Out:
# Missing Summary             Total  Percent
# Attributes
# Overall fitness center       7692    78.57
# Accuracy of bill             4686    47.87
# Bar ambiance                 4566    46.64
# Breakfast quality            4254    43.45
# Ease of making reservation   3650    37.28
# Internet quality             3649    37.27
# Cleanliness of bathroom       566     5.78
# Overall Experience              0     0.00
# Attitude of hotel staff         0     0.00
# Cleanliness of room             0     0.00
# Quietness of room               0     0.00

# %%
target, feature =splitTarget(cleanedDf, 'Overall Experience')
feature
# Out:
#       Internet quality  Ease of making reservation  Attitude of hotel staff  \
# 0                 10.0                         8.0                     10.0
# 1                 10.0                        10.0                     10.0
# 2                  NaN                         NaN                      9.0
# 3                  NaN                         NaN                      8.0
# 4                  NaN                         NaN                     10.0
# 5                  9.0                         9.0                      9.0
# 6                  9.0                         9.0                      7.0
# 7                  NaN                         NaN                      9.0
# 8                  9.0                         9.0                      9.0
# 9                 10.0                        10.0                     10.0
# 10                 8.0                        10.0                     10.0
# ...

# %%
cleanedMissingDf
# Out:
# Missing Summary             Total  Percent
# Attributes
# Overall fitness center       7692    78.57
# Accuracy of bill             4686    47.87
# Bar ambiance                 4566    46.64
# Breakfast quality            4254    43.45
# Ease of making reservation   3650    37.28
# Internet quality             3649    37.27
# Cleanliness of bathroom       566     5.78
# Overall Experience              0     0.00
# Attitude of hotel staff         0     0.00
# Cleanliness of room             0     0.00
# Quietness of room               0     0.00

# %%
imputedDf, imputed_missingDf = imputedFrame(cleanedDf, 'knn')
# Out:
# How many nearest Neighbors? 3
# Imputing row 1/9790 with 1 missing, elapsed time: 33.865
# Imputing row 101/9790 with 4 missing, elapsed time: 33.953
# Imputing row 201/9790 with 4 missing, elapsed time: 34.016
# Imputing row 301/9790 with 0 missing, elapsed time: 34.093
# Imputing row 401/9790 with 1 missing, elapsed time: 34.231
# Imputing row 501/9790 with 0 missing, elapsed time: 34.510
# Imputing row 601/9790 with 4 missing, elapsed time: 34.638
# Imputing row 701/9790 with 0 missing, elapsed time: 34.801
# Imputing row 801/9790 with 1 missing, elapsed time: 34.980
# Imputing row 901/9790 with 7 missing, elapsed time: 35.176
# Imputing row 1001/9790 with 3 missing, elapsed time: 35.372
# Imputing row 1101/9790 with 1 missing, elapsed time: 35.523
# Imputing row 1201/9790 with 2 missing, elapsed time: 35.609
# Imputing row 1301/9790 with 1 missing, elapsed time: 35.821
# Imputing row 1401/9790 with 5 missing, elapsed time: 35.995
# ...

# %%
imputed_missingDf
# Out:
# Missing Summary             Total  Percent
# Attributes
# Overall Experience              0      0.0
# Internet quality                0      0.0
# Ease of making reservation      0      0.0
# Attitude of hotel staff         0      0.0
# Cleanliness of room             0      0.0
# Quietness of room               0      0.0
# Breakfast quality               0      0.0
# Cleanliness of bathroom         0      0.0
# Bar ambiance                    0      0.0
# Accuracy of bill                0      0.0
# Overall fitness center          0      0.0

# %%
imputedDf.head()
# Out:
#    Overall Experience  Internet quality  Ease of making reservation  \
# 0                 9.0              10.0                         8.0
# 1                10.0              10.0                        10.0
# 2                 8.0               8.0                         9.0
# 3                 8.0               8.0                         9.0
# 4                 5.0               9.0                        10.0
#
#    Attitude of hotel staff  Cleanliness of room  Quietness of room  \
# 0                     10.0                 10.0                9.0
# 1                     10.0                 10.0               10.0
# 2                      9.0                 10.0               10.0
# 3                      8.0                  9.0                9.0
# 4                     10.0                 10.0               10.0
#
#    Breakfast quality  Cleanliness of bathroom  Bar ambiance  Accuracy of bill  \
# ...

# %%
target, features = splitTarget(imputedDf, 'Overall Experience')

# %%
distribution(features)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-5449a2d69628> in <module>()
# ----> 1 distribution(features)
#
# <ipython-input-7-37d02f01267d> in distribution(data)
#       2     cols = list(data.columns)
#       3     for col in cols:
# ----> 4         sns.distplot(data[col], kde=True, rug=True)
#       5         plt.show()
#
# ~/anaconda3/lib/python3.5/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     226         rug_color = rug_kws.pop("color", color)
#     227         axis = "y" if vertical else "x"
# --> 228         rugplot(a, axis=axis, ax=ax, color=rug_color, **rug_kws)
#     229         if rug_color != color:
#     230             rug_kws["color"] = rug_color
#
# ...

# %%
target = DataFrame(target)
distribution(target)

# %%
round(cleanedDf.describe(),2)
# Out:
#        Overall Experience  Internet quality  Ease of making reservation  \
# count             9790.00           6141.00                     6140.00
# mean                 8.40              8.91                        8.81
# std                  1.86              1.36                        1.64
# min                  1.00              1.00                        1.00
# 25%                  8.00              8.00                        8.00
# 50%                  9.00              9.00                        9.00
# 75%                 10.00             10.00                       10.00
# max                 10.00             10.00                       10.00
#
#        Attitude of hotel staff  Cleanliness of room  Quietness of room  \
# count                  9790.00              9790.00            9790.00
# mean                      8.82                 8.81               8.28
# std                       1.75                 1.64               2.18
# ...

# %%
round(imputedDf.describe(),2)
# Out:
#        Overall Experience  Internet quality  Ease of making reservation  \
# count             9790.00           9790.00                     9790.00
# mean                 8.40              8.88                        8.76
# std                  1.86              1.36                        1.62
# min                  1.00              1.00                        1.00
# 25%                  8.00              8.00                        8.00
# 50%                  9.00              9.00                        9.00
# 75%                 10.00             10.00                       10.00
# max                 10.00             10.00                       10.00
#
#        Attitude of hotel staff  Cleanliness of room  Quietness of room  \
# count                  9790.00              9790.00            9790.00
# mean                      8.82                 8.81               8.28
# std                       1.75                 1.64               2.18
# ...

# %%
round(imputedDf.describe(),2)
# Out:
#        Overall Experience  Internet quality  Ease of making reservation  \
# count             9790.00           9790.00                     9790.00
# mean                 8.40              8.88                        8.76
# std                  1.86              1.36                        1.62
# min                  1.00              1.00                        1.00
# 25%                  8.00              8.00                        8.00
# 50%                  9.00              9.00                        9.00
# 75%                 10.00             10.00                       10.00
# max                 10.00             10.00                       10.00
#
#        Attitude of hotel staff  Cleanliness of room  Quietness of room  \
# count                  9790.00              9790.00            9790.00
# mean                      8.82                 8.81               8.28
# std                       1.75                 1.64               2.18
# ...

# %%
DataFrame(imputedDf.var()) - DataFrame(cleanedDf.var())
# Out:
#                                    0
# Overall Experience          0.000000
# Internet quality            0.003442
# Ease of making reservation -0.062828
# Attitude of hotel staff     0.000000
# Cleanliness of room         0.000000
# Quietness of room           0.000000
# Breakfast quality          -0.609274
# Cleanliness of bathroom     0.007894
# Bar ambiance               -0.817628
# Accuracy of bill           -0.803228
# Overall fitness center     -0.890112

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, Range1d, LabelSet, Label
from bokeh.models import NumeralTickFormatter
output_notebook()

factors = list(reversed(missingDf.index))
x1 = (missingDf['Percent'].sort_values(ascending=True)/100)
source = ColumnDataSource(dict(x=round(x1,2),y=factors))

p = figure(y_range=factors, plot_width=800, plot_height=600)
p.outline_line_width = 8
p.outline_line_alpha = 0.3
p.outline_line_color = "navy"
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5

p.xaxis.axis_label = "Percent Missing (%)"
p.xaxis.axis_label_text_font_size = "12pt"
#p.xaxis.axis_line_width = 2
#p.xaxis.axis_line_color = "red"

# change just some things about the y-axes
p.yaxis.axis_label = "Attributes"
#p.yaxis.axis_line_width = 2
#p.yaxis.major_label_text_color = "orange"
p.yaxis.major_label_orientation = "horizontal"
p.yaxis.axis_label_text_font_size = "12pt"

# change things on all axes
p.axis.minor_tick_in = -3
p.axis.minor_tick_out = 6


#p.title.text_color = "olive"
#p.title.text_font = "times"
p.title.text_font_style = "bold"
p.title.align = 'center'
p.title.text = "Missing Data Summary"
p.title.align = "center"
p.title.text_font_size = "20px"

p.xaxis[0].formatter = NumeralTickFormatter(format="0.0%")
p.xaxis.bounds = (0.0, 100.0)

labels = LabelSet(x='x', y='y', text='x', level='glyph',
        x_offset= 5, y_offset= -10 , source=source, render_mode='canvas')

p.x_range = Range1d(0, 1)
p.hbar(y=factors, height=0.6, left=0,
       right=x1, color="darkblue")
p.add_layout(labels)

p.min_border_top = 50
p.min_border_bottom = 50
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0c08e819-4903-4777-b277-b7c64ec8cca1">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="01b91977-bd61-437b-a0c3-09dce869f2f9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
# ...

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, Range1d, LabelSet, Label, NumeralTickFormatter
output_notebook()

def plotMissingDataSummary(df):
    factors = list(reversed(df.index))
    values = (df['Percent'].sort_values(ascending=True)/100)
    source = ColumnDataSource(dict(x=round(values,2), y=factors))
    
    p = figure(y_range=factors, plot_width=800, plot_height=600)
    p.hbar(y=factors, height=0.6, left=0, right=values, color="darkblue")

    labels = LabelSet(x='x', y='y', text='x', level='glyph', x_offset=5, y_offset=-10, source=source, render_mode='canvas')
    p.add_layout(labels)
    
    #---------------------------------PLOT FORMATTING---------------------------------------#
    
    #-----OUTLINE-----#
    p.outline_line_width = 8
    p.outline_line_alpha = 0.3
    p.outline_line_color = "navy"
    
    #-----BACKGROUND-----#
    p.background_fill_color = "beige"
    p.background_fill_alpha = 0.5
    
    #-----X-AXIS-----#
    p.xaxis.axis_label = "Percent Missing (%)"
    p.xaxis.axis_label_text_font_size = "12pt"
    #p.xaxis.axis_line_width = 2
    #p.xaxis.axis_line_color = "red"
    
    #-----Y-AXIS-----#
    p.yaxis.axis_label = "Attributes"
    p.yaxis.major_label_orientation = "horizontal"
    p.yaxis.axis_label_text_font_size = "12pt"
    #p.yaxis.axis_line_width = 2
    #p.yaxis.major_label_text_color = "orange"
    
    #-----TITLE-----#
    p.title.text_font_style = "bold"
    p.title.align = 'center'
    p.title.text = "Missing Data Summary"
    p.title.align = "center"
    p.title.text_font_size = "20px"
    #p.title.text_color = "olive"
    #p.title.text_font = "times"
    
    #-----TICK-FORMAT-----#
    p.xaxis[0].formatter = NumeralTickFormatter(format="0.0%")

    #-----BOUNDS-----#
    p.xaxis.bounds = (0.0, 100.0)
    p.x_range = Range1d(0, 1)
    
    #-----BORDERS-----#
    p.min_border_top = 50
    p.min_border_bottom = 50
    
    #---------------------------------PLOT FORMATTING---------------------------------------#
    if any(list(droppedFrameMissing['Total']>0)):
        return show(p)
    else: 
        return ("Status: No Missing Values")
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5186b2b9-5ae2-4e03-9687-5f0c738539b9">Loading BokehJS ...</span>
#     </div>

# %%
import os
from pandas import Series, DataFrame

def wordCounter(text):
    cwd = os.getcwd()
    file = open(cwd + '/' + text, 'r')
    
    counter={}
    for word in file.read().split():
        if word not in counter:
            counter[word] = 1
        else:
            counter[word] += 1

    counterFrame = Series(counter).to_frame()
    counterFrame.columns = ['Count']
    counterFrame.name = 'Word-Count'
    counterFrame.index.name = 'Words'

    return counterFrame.sort_values('Count', ascending=False)

# %%
import pandas as pd
def missingSummary(data):
    total = data.isnull().sum()
    percent = data.isnull().sum() / data.isnull().count() * 100
    missingFrame = round(pd.concat([total, percent], axis=1, keys=['Total', 'Percent']).sort_values('Percent', 
                                                                                             ascending=False),2)
    missingFrame.name = 'Missing-Data-Summary'
    
    plotMissingDataSummary(missingFrame)
    
    return missingFrame

# %%
import numpy as np
def dropColRows(data, missingDf, ColCutoff, RowCutoff):
    cols_to_drop = list(missingDf.loc[missingDf['Percent'] >= ColCutoff].index)
    rows_to_drop = list(missingDf.loc[missingDf['Percent'] <= RowCutoff].index)
    
    droppedFrame = data.copy()
    droppedFrame = droppedFrame.drop(cols_to_drop, axis=1)
    droppedFrame = droppedFrame.dropna(subset=rows_to_drop, how='any')
    
    droppedFrame.reindex(np.arange(len(droppedFrame)))
    droppedFrame.name='Dropped-Df'
    
    droppedFrameMissing = missingSummary(droppedFrame)
    
    return droppedFrame, droppedFrameMissing

# %%
df = pd.read_excel('SampleData-2.xls')
missingDf = missingSummary(df)
droppedFrame, droppedFrameMissing = dropColRows(df, missingDf,80, 5)

# %%
missingDf = missingSummary(df)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e5bfe9d4-08a0-4bd0-92cb-913243f7b4bf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
cleanedDf, cleaned_MissingDf = dropColRows(df, missingDf, 80,5)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a784217c-544e-4d32-92ec-b9e3ce8ef9cb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
from sklearn.preprocessing import Imputer
from fancyimpute import KNN
from pandas import DataFrame, Series

def imputation(data, process):
    if process in ('bfill', 'ffill'):
        imputedDf = data.fillna(method=process, inplace=False)
    elif process in ('mean', 'median', 'most_frequent'):
        imp = Imputer(missing_values=np.NaN, strategy=process, axis=0, copy=True)
        imputedDf = imp.fit_transform(data)
        imputedDf = round(DataFrame(imputedDf),0)
    else:
        nn = int(input('How many nearest neighbors? '))
        imputedDf = KNN(k=nn).complete(data)
        imputedDf = round(DataFrame(imputedDf),0)
        
    imputedDf.reindex(np.arange(len(imputedDf)))
    imputedDf.columns = data.columns
    
    imputed_MissingDf = missingSummary(imputedDf)
    
    return imputedDf, imputed_MissingDf

# %%
x, y = imputation(cleanedDf, 'most_frequent')
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7b6c1d63-30e9-4cff-95d4-9356ea702e63"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
def plotPractice(df):
    features = list(reversed(df.index))
    vals = df['Percent'].sort_values(ascending=True)/100
    source= ColumnDataSource(dict(x=round(vals,2), y=features))
    
    p = figure(y_range=features, plot_width=800, plot_height=600)
    p.hbar(y=features, height=0.6, left=0, right=vals, color="darkblue")
    
    labels = LabelSet(x='x', y='y', text='x', level='glyph', x_offset=0, y_offset=-10, source=source, render_mode='canvas')
    p.add_layout(labels)
    
    return show(p)

# %%
plotPractice(cleaned_MissingDf)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="42fe7631-79b1-4ca0-88e3-7cad5990b6e7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...
